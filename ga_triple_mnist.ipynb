# %%
# !git clone https://huggingface.co/datasets/khushpatel2002/triple-mnist
# Out:
# fatal: destination path 'triple-mnist' already exists and is not an empty directory.

# %%
import os
import re
import cv2
import time
import pandas
import random
import zipfile
import numpy as np
from tqdm import tqdm
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

from random import choice
from tensorflow.keras import layers, models
from tensorflow.keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

# %%
class GeneticAlgorithm:
    # Initializes the Genetic Algorithm with the required parameters and training/validation data.
    def __init__(self, population_size, num_generations, mutation_rate, x_train, y_train, x_val, y_val, verbose=False):
        self.population_size = population_size  # The number of individuals in the population.
        self.num_generations = num_generations  # The number of generations to evolve.
        self.mutation_rate = mutation_rate  # The rate at which mutations occur.
        self.x_train = x_train  # Training data inputs.
        self.y_train = y_train  # Training data outputs.
        self.x_val = x_val  # Validation data inputs.
        self.y_val = y_val  # Validation data outputs.
        self.verbose = verbose  # Whether to print detailed logs.
        self.gene_pool = set()  # Ensures all genes are unique by storing them.
        self.population = [self.create_unique_gene() for _ in range(population_size)]  # Initialize the population with unique genes.
        self.current_best_gene = None  # Stores the best gene found across all generations.
        if self.verbose:
            print(f"Initialized GA with {population_size} genes.")

    # Generates a new gene with randomly chosen parameters.
    def create_gene(self):
        # Define possible filter sizes
        filter_sizes = [3, 5, 7, 9]  # Odd numbers between 3 and 11

        # Generate gene with random selections
        gene = [
            random.randint(8, 150),  # Batch size randomly chosen between 8 and 100
            random.randint(8, 100),  # Number of filters for the first layer
            random.choice(filter_sizes),  # Filter size for the first layer
            random.randint(8, 100),  # Number of filters for the second layer
            random.choice(filter_sizes)   # Filter size for the second layer
        ]

        return gene

    # Ensures each gene is unique before adding it to the population.
    def create_unique_gene(self):
        while True:
            new_gene = self.create_gene()
            gene_tuple = tuple(new_gene)
            if gene_tuple not in self.gene_pool:
                self.gene_pool.add(gene_tuple)
                if self.verbose:
                    print(f"Added unique gene: {new_gene}")
                return new_gene

    # Orchestrates the evolution process across generations.
    def evolve(self):
        history = []

        parameter_history = []
        fitness_history = []
        for generation in range(self.num_generations):
            if self.verbose:
                print(f"\nStarting Generation {generation+1}/{self.num_generations}")
            fitness_scores = self.evaluate_population()
            fitness_history.append(fitness_scores)

            best_idx = fitness_scores.index(max(fitness_scores))
            best_gene = self.population[best_idx]
            self.current_best_gene = best_gene
            history.append((generation, best_gene, max(fitness_scores)))

            parameter_history.append([gene for gene in self.population])
            if self.verbose:
                print(f"Best gene: {best_gene} with fitness: {max(fitness_scores)}")
            self.selection(fitness_scores)
            self.crossover()
            # self.mutation()
            
        return history, parameter_history, fitness_history

    # Evaluates the current population by training and testing the CNN with each individual's gene.
    def evaluate_population(self):
        fitness_scores = []
        for gene in self.population:
            # Extract gene information
            batch_size = gene[0]
            num_filters1 = gene[1]
            filter_size1 = gene[2]
            num_filters2 = gene[3]
            filter_size2 = gene[4]

            # Set layer configuration for CNN model
            layer_config = [num_filters1, filter_size1, num_filters2, filter_size2]
            model = CNNModel(layer_config, self.verbose)
            model.train(self.x_train, self.y_train, self.x_val, self.y_val, batch_size)
            fitness = model.evaluate(self.x_val, self.y_val)
            fitness_scores.append(fitness)
            if self.verbose:
                print(f"Gene {gene} evaluated with fitness: {fitness}")

        return fitness_scores

    # Selects the best-performing individuals to continue to the next generation.
    def selection(self, fitness_scores):
        sorted_indices = sorted(range(len(fitness_scores)), key=lambda i: fitness_scores[i], reverse=True)
        self.population = [self.population[i] for i in sorted_indices[:self.population_size // 2]]
        if self.verbose:
            print("Selection phase completed. Population halved.")

    # Combines genes from two parents to create new individuals.
    def crossover(self):
        next_generation = self.population.copy()
        if self.verbose:
            print("Crossover phase initiated.")
        attempts = 0
        max_attempts = 10  # Maximum attempts to generate a unique child

        while len(next_generation) < self.population_size and attempts < max_attempts:
            parent1, parent2 = random.sample(self.population, 2)
            child = [random.choice(gene) for gene in zip(parent1, parent2)]
            child_gene_tuple = tuple(child)
            if child_gene_tuple not in self.gene_pool:
                self.gene_pool.add(child_gene_tuple)
                next_generation.append(child)
                if self.verbose:
                    print(f"Crossover produced: {child}")
            attempts += 1

        if attempts == max_attempts:
            print("Max crossover attempts reached, proceeding with available population.")
        self.population = next_generation

    def get_population(self):
      return self.population

    def mutation(self):
        # Determine how many individuals to mutate based on the mutation rate
        num_to_mutate = int(len(self.population) * self.mutation_rate)
        selected_indices = random.sample(range(len(self.population)), num_to_mutate)

        for index in selected_indices:
            gene = self.population[index].copy()  # Make a copy to mutate
            mutation_index = random.randint(0, 4)  # Choose a random index in the gene to mutate

            if mutation_index in [2, 4]:
                gene[mutation_index] = random.choice([3, 5, 7, 9])
            elif mutation_index in [1, 3]:
                gene[mutation_index] = random.randint(8, 100)
            elif mutation_index == 0:
                gene[mutation_index] = random.randint(8, 150)  # Batch sizes can also be dynamic

            # Update the gene in the population
            if self.verbose:
                print(f"Mutated gene at index {index} from {self.population[index]} to {gene}")
            self.population[index] = gene

# %%
class CNNModel:
    # Constructor with parameters for the layer configuration and a verbosity flag
    def __init__(self, layer_config, verbose=False):
        # Check if the layer configuration contains exactly four integers, raise an error if not
        if len(layer_config) != 4:
            raise ValueError("layer_config must contain exactly four integers")
        # Unpack the layer configuration into individual variables for two convolutional layers, set 
        #   the verbosity and build the model, based on the layer configuration parameters.
        self.num_filters1, self.filter_size1, self.num_filters2, self.filter_size2 = layer_config
        self.verbose = verbose
        self.model = self.build_model()

    # Method to construct the neural network model
    def build_model(self):
        # Create a sequential model, meaning the layers are stacked linearly
        model = models.Sequential([
            # First convolutional layer with specified number of filters and filter size, and ReLU activation
            layers.Conv2D(self.num_filters1, (self.filter_size1, self.filter_size1), activation='relu', input_shape=(28, 28, 1)),
            # Second convolutional layer with padding to keep dimensions, and ReLU activation
            layers.Conv2D(self.num_filters2, (self.filter_size2, self.filter_size2), activation='relu', padding='same'),
            # Max pooling layer to reduce spatial dimensions of the output from the previous convolutional layer
            layers.MaxPooling2D((2, 2)),
            # Flatten the 3D output to 1D to feed into the dense layer
            layers.Flatten(),
            # Dense layer to output predictions for 10 classes using softmax activation
            layers.Dense(10, activation='softmax')
        ])
        # Compile the model with the Adam optimizer and sparse categorical crossentropy loss, also tracking accuracy
        model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
        return model  # Return the compiled model

    # Method to train the model on training data with validation, also using early stopping
    def train(self, x_train, y_train, x_val, y_val, batch_size, epochs=1):
        # Setup EarlyStopping
        early_stopping = EarlyStopping(
            monitor='val_loss',
            patience=3,
            verbose=self.verbose,
            restore_best_weights=True
        )
        if self.verbose:
            print(f"Training model with batch size {batch_size} and filters: [{self.num_filters1}, {self.num_filters2}].")
        self.model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
                       validation_data=(x_val, y_val), verbose=self.verbose, callbacks=[early_stopping])

    # Method to evaluate the model on validation data and return the accuracy
    def evaluate(self, x_val, y_val):
        val_loss, val_acc = self.model.evaluate(x_val, y_val, verbose=self.verbose)
        return val_acc

# %%
# Define paths
trainpath = r'triple-mnist/train'
testpath = r'triple-mnist/test'
valpath = r'triple-mnist/val'

# Get list of directories in each path
train_dir = [name for name in os.listdir(trainpath) if os.path.isdir(os.path.join(trainpath, name))]
test_dir  = [name for name in os.listdir(testpath) if os.path.isdir(os.path.join(testpath, name))]
val_dir =  [name for name in os.listdir(valpath) if os.path.isdir(os.path.join(valpath, name))]

# Sort directories
train_dir.sort()
test_dir.sort()
val_dir.sort()

# Get list of files in each path
train_files_name = [name for name in os.listdir(trainpath)]
test_files_name = [name for name in os.listdir(testpath)]
val_files_name =  [name for name in os.listdir(valpath)]

# Define full paths
TRAINDIR = r'triple-mnist/train'
TESTDIR = r'triple-mnist/test'
VALDIR = r'triple-mnist/val'

# %%
# Empty list to store the training labels
label_y = []

def create_training_data():

    # Empty list to store each number image that is sent by each_digit function
    train_X = []

    # iterate over training directory
    for image_dir in train_dir:
        path = os.path.join(TRAINDIR,image_dir)  # path of directories

        # iterate over image directories in the training directory
        for img in tqdm(os.listdir(path)):  # iterate over each image per dogs and cats
            try:
                # extract andn convert to array
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)

                # splitting digits by spaces between them (dividing image into 3 parts)
                img_array1 = img_array[:, :img_array.shape[1]//3]
                img_array2 = img_array[:, img_array.shape[1]//3: img_array.shape[1]//3 + img_array.shape[1]//3]
                img_array3 = img_array[:, img_array.shape[1]//3 + img_array.shape[1]//3 :]

                # append the splitted images of each digit
                train_X.append(each_digit(img_array1))
                train_X.append(each_digit(img_array2))
                train_X.append(each_digit(img_array3))

                # append the relative positioned number from the name of the image directory
                label_y.append(str(image_dir)[0])
                label_y.append(str(image_dir)[1])
                label_y.append(str(image_dir)[2])

            # in the interest in keeping the output clean...
            except Exception as e:
                pass
    return train_X

# %%
# Empty list to store the validation labels
val_y = []
def create_val_data():

    # Empty list to store each number image that is sent by each_digit function
    val_X = []

    # iterate over training directory
    for image_dir in val_dir:
        path = os.path.join(VALDIR,image_dir)

        # iterate over image directories in the training directory
        for img in tqdm(os.listdir(path)):
            try:
                # extract and convert to array
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)

                # splitting digits by spaces between them (dividing image into 3 parts)
                img_array1 = img_array[:, :img_array.shape[1]//3]
                img_array2 = img_array[:, img_array.shape[1]//3: img_array.shape[1]//3 + img_array.shape[1]//3]
                img_array3 = img_array[:, img_array.shape[1]//3 + img_array.shape[1]//3 :]

                # append the splitted images of each digit
                val_X.append(each_digit(img_array1))
                val_X.append(each_digit(img_array2))
                val_X.append(each_digit(img_array3))


                # append the relative positioned number from the name of the image directory
                val_y.append(str(image_dir)[0])
                val_y.append(str(image_dir)[1])
                val_y.append(str(image_dir)[2])

            # in the interest in keeping the output clean...
            except Exception as e:
                pass
    return val_X

# %%
# Empty list to store the test labels
test_y = []

def create_test_data():

    # Empty list to store each number image that is sent by each_digit function
    test_X = []


    # iterate over training directory
    for image_dir in test_dir:
        path = os.path.join(TESTDIR,image_dir)

        for img in tqdm(os.listdir(path)):
            try:
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)

                img_array1 = img_array[:, :img_array.shape[1]//3]
                img_array2 = img_array[:, img_array.shape[1]//3: img_array.shape[1]//3 + img_array.shape[1]//3]
                img_array3 = img_array[:, img_array.shape[1]//3 + img_array.shape[1]//3 :]

                test_X.append(each_digit(img_array1))
                test_X.append(each_digit(img_array2))
                test_X.append(each_digit(img_array3))

                test_y.append(str(image_dir)[0])
                test_y.append(str(image_dir)[1])
                test_y.append(str(image_dir)[2])

            except Exception as e:
                pass
    return test_X

# %%
def each_digit(image):

      ret, thresh = cv2.threshold(image.copy(), 0, 255, cv2.THRESH_BINARY_INV)

      contours, _  = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

      for c in contours:
       x,y,w,h = cv2.boundingRect(c)

       cv2.rectangle(image, (x,y), (x+w, y+h), color=(0, 255, 0), thickness=2)

       digit = thresh[y:y+h, x:x+w]

       resized_digit = cv2.resize(digit, (28,28))

       return resized_digit

# %%
td_array = np.array(create_training_data())
val_array = np.array(create_val_data())
test_array = np.array(create_test_data())
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.72it/s]
# 100%|██████████| 100/100 [00:00<00:00, 223.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 237.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 227.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 207.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 209.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 166.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 133.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 215.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 207.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 174.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 150.67it/s]
# 100%|██████████| 100/100 [00:00<00:00, 158.27it/s]
# 100%|██████████| 100/100 [00:01<00:00, 85.87it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 154.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 216.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 202.55it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.15it/s]
# 100%|██████████| 100/100 [00:00<00:00, 218.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 161.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.18it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 204.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.04it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.04it/s]
# 100%|██████████| 100/100 [00:00<00:00, 195.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.52it/s]
# 100%|██████████| 100/100 [00:00<00:00, 198.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 162.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 208.93it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 139.12it/s]
# 100%|██████████| 100/100 [00:00<00:00, 199.87it/s]
# 100%|██████████| 100/100 [00:00<00:00, 214.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 164.89it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 207.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.36it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.41it/s]
# 100%|██████████| 100/100 [00:00<00:00, 218.89it/s]
# 100%|██████████| 100/100 [00:00<00:00, 230.61it/s]
# 100%|██████████| 100/100 [00:00<00:00, 208.61it/s]
# 100%|██████████| 100/100 [00:00<00:00, 237.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 233.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.79it/s]
# 100%|██████████| 100/100 [00:00<00:00, 218.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 163.57it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.93it/s]
# 100%|██████████| 100/100 [00:00<00:00, 163.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 169.14it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 133.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 168.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 161.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 121.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.19it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.02it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.38it/s]
# 100%|██████████| 100/100 [00:00<00:00, 140.96it/s]
# 100%|██████████| 100/100 [00:00<00:00, 162.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.28it/s]
# 100%|██████████| 100/100 [00:00<00:00, 195.15it/s]
# 100%|██████████| 100/100 [00:00<00:00, 191.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 160.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.07it/s]
# 100%|██████████| 100/100 [00:01<00:00, 97.33it/s]
# 100%|██████████| 100/100 [00:00<00:00, 158.37it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.61it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 164.54it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.36it/s]
# 100%|██████████| 100/100 [00:00<00:00, 163.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 139.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 149.54it/s]
# 100%|██████████| 100/100 [00:00<00:00, 154.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 166.04it/s]
# 100%|██████████| 100/100 [00:00<00:00, 159.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 136.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.18it/s]
# 100%|██████████| 100/100 [00:00<00:00, 174.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 166.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.05it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.95it/s]
# 100%|██████████| 100/100 [00:00<00:00, 139.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 155.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.95it/s]
# 100%|██████████| 100/100 [00:00<00:00, 162.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 168.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 136.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 149.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 161.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 158.18it/s]
# 100%|██████████| 100/100 [00:00<00:00, 161.34it/s]
# 100%|██████████| 100/100 [00:00<00:00, 144.36it/s]
# 100%|██████████| 100/100 [00:00<00:00, 162.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.06it/s]
# 100%|██████████| 100/100 [00:00<00:00, 209.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 209.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 191.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 213.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 151.51it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.02it/s]
# 100%|██████████| 100/100 [00:00<00:00, 152.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 127.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 169.28it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 148.15it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 204.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.61it/s]
# 100%|██████████| 100/100 [00:00<00:00, 198.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 129.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 204.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.05it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 197.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.89it/s]
# 100%|██████████| 100/100 [00:00<00:00, 144.41it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.98it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.80it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.50it/s]
# 100%|██████████| 100/100 [00:00<00:00, 195.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 195.89it/s]
# 100%|██████████| 100/100 [00:00<00:00, 144.79it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.41it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 163.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.42it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.96it/s]
# 100%|██████████| 100/100 [00:00<00:00, 145.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.15it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 169.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 132.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 111.69it/s]
# 100%|██████████| 100/100 [00:00<00:00, 111.37it/s]
# 100%|██████████| 100/100 [00:00<00:00, 130.57it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.29it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 159.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.87it/s]
# 100%|██████████| 100/100 [00:00<00:00, 162.18it/s]
# 100%|██████████| 100/100 [00:00<00:00, 217.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 217.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 210.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 208.42it/s]
# 100%|██████████| 100/100 [00:00<00:00, 148.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.18it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.02it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.04it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.19it/s]
# 100%|██████████| 100/100 [00:00<00:00, 230.17it/s]
# 100%|██████████| 100/100 [00:00<00:00, 141.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 197.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 242.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 214.28it/s]
# 100%|██████████| 100/100 [00:00<00:00, 219.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 219.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.80it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 135.79it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 208.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.69it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 191.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 131.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 156.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 198.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 139.28it/s]
# 100%|██████████| 100/100 [00:00<00:00, 202.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 197.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 154.70it/s]
# 100%|██████████| 100/100 [00:00<00:00, 147.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 199.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.95it/s]
# 100%|██████████| 100/100 [00:00<00:00, 206.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.80it/s]
# 100%|██████████| 100/100 [00:00<00:00, 155.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 197.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 195.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 164.57it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 138.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 160.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.50it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.67it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 128.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 202.81it/s]
# 100%|██████████| 100/100 [00:00<00:00, 219.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 191.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 148.88it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.85it/s]
# 100%|██████████| 100/100 [00:00<00:00, 202.88it/s]
# 100%|██████████| 100/100 [00:00<00:00, 169.42it/s]
# 100%|██████████| 100/100 [00:00<00:00, 236.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.70it/s]
# 100%|██████████| 100/100 [00:00<00:00, 214.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 148.34it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.50it/s]
# 100%|██████████| 100/100 [00:00<00:00, 139.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 202.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.19it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.96it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.34it/s]
# 100%|██████████| 100/100 [00:00<00:00, 225.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 130.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.36it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 161.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.06it/s]
# 100%|██████████| 100/100 [00:00<00:00, 208.89it/s]
# 100%|██████████| 100/100 [00:00<00:00, 129.88it/s]
# 100%|██████████| 100/100 [00:00<00:00, 215.34it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.52it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.04it/s]
# 100%|██████████| 100/100 [00:00<00:00, 153.95it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.82it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.85it/s]
# 100%|██████████| 100/100 [00:00<00:00, 174.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 154.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 129.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.69it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.72it/s]
# 100%|██████████| 100/100 [00:00<00:00, 216.37it/s]
# 100%|██████████| 100/100 [00:00<00:00, 164.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 139.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.79it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.70it/s]
# 100%|██████████| 100/100 [00:00<00:00, 213.61it/s]
# 100%|██████████| 100/100 [00:00<00:00, 198.02it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.55it/s]
# 100%|██████████| 100/100 [00:00<00:00, 198.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 163.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 151.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 203.61it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.41it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 131.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 220.79it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 163.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 203.02it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.05it/s]
# 100%|██████████| 100/100 [00:00<00:00, 137.14it/s]
# 100%|██████████| 100/100 [00:00<00:00, 154.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 202.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.14it/s]
# 100%|██████████| 100/100 [00:00<00:00, 145.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 204.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 235.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.23it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 208.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 168.98it/s]
# 100%|██████████| 100/100 [00:00<00:00, 137.14it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 231.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 223.69it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 206.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 126.72it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.81it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 162.82it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 191.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 126.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 197.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 163.55it/s]
# 100%|██████████| 100/100 [00:00<00:00, 155.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 236.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 208.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 191.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 210.04it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.42it/s]
# 100%|██████████| 100/100 [00:00<00:00, 166.14it/s]
# 100%|██████████| 100/100 [00:00<00:00, 203.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.18it/s]
# 100%|██████████| 100/100 [00:00<00:00, 232.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 132.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 155.37it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.93it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 160.89it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.29it/s]
# 100%|██████████| 100/100 [00:00<00:00, 174.96it/s]
# 100%|██████████| 100/100 [00:00<00:00, 174.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 168.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 140.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.19it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.72it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.89it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 145.29it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.29it/s]
# 100%|██████████| 100/100 [00:00<00:00, 214.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 145.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 203.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 203.88it/s]
# 100%|██████████| 100/100 [00:00<00:00, 145.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 155.70it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 122.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 144.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 168.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.33it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.05it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.96it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.80it/s]
# 100%|██████████| 100/100 [00:00<00:00, 151.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 133.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.72it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 211.55it/s]
# 100%|██████████| 100/100 [00:00<00:00, 207.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 148.88it/s]
# 100%|██████████| 100/100 [00:00<00:00, 218.48it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.82it/s]
# 100%|██████████| 100/100 [00:00<00:00, 145.50it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 219.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.29it/s]
# 100%|██████████| 100/100 [00:00<00:00, 130.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.41it/s]
# 100%|██████████| 100/100 [00:00<00:00, 215.23it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.61it/s]
# 100%|██████████| 100/100 [00:00<00:00, 207.22it/s]
# 100%|██████████| 100/100 [00:00<00:00, 144.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 209.06it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 120.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.57it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 128.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 155.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 150.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 168.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 210.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 208.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 116.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 153.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 135.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 138.04it/s]
# 100%|██████████| 100/100 [00:00<00:00, 150.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 130.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.61it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.38it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 132.05it/s]
# 100%|██████████| 100/100 [00:00<00:00, 207.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.19it/s]
# 100%|██████████| 100/100 [00:00<00:00, 191.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 219.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 141.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 148.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 154.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 126.28it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.61it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.48it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.06it/s]
# 100%|██████████| 100/100 [00:00<00:00, 119.15it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 146.87it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.98it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 146.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.81it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 109.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 228.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 158.42it/s]
# 100%|██████████| 100/100 [00:00<00:00, 226.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.47it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 161.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 238.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 250.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.87it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 209.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 163.37it/s]
# 100%|██████████| 100/100 [00:00<00:00, 152.80it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 218.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 206.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 216.48it/s]
# 100%|██████████| 100/100 [00:00<00:00, 156.18it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 169.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 215.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 204.93it/s]
# 100%|██████████| 100/100 [00:00<00:00, 145.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 213.37it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.14it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 126.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 166.81it/s]
# 100%|██████████| 100/100 [00:00<00:00, 174.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 228.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 147.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 197.52it/s]
# 100%|██████████| 100/100 [00:00<00:00, 195.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 137.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.12it/s]
# 100%|██████████| 100/100 [00:00<00:00, 212.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.96it/s]
# 100%|██████████| 100/100 [00:00<00:00, 206.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 134.47it/s]
# 100%|██████████| 100/100 [00:00<00:00, 198.50it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.52it/s]
# 100%|██████████| 100/100 [00:00<00:00, 141.28it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.95it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 254.22it/s]
# 100%|██████████| 100/100 [00:00<00:00, 239.12it/s]
# 100%|██████████| 100/100 [00:00<00:00, 211.98it/s]
# 100%|██████████| 100/100 [00:00<00:00, 130.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 222.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 208.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 225.52it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 124.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 224.79it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.51it/s]
# 100%|██████████| 100/100 [00:00<00:00, 209.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 159.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.50it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 139.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 152.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 216.15it/s]
# 100%|██████████| 100/100 [00:00<00:00, 130.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 209.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.29it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 140.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.55it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 212.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 138.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 166.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.70it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 153.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 208.52it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.55it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.25it/s]
# 100%|██████████| 100/100 [00:01<00:00, 92.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 105.29it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.88it/s]
# 100%|██████████| 100/100 [00:00<00:00, 124.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 163.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 215.95it/s]
# 100%|██████████| 100/100 [00:00<00:00, 197.67it/s]
# 100%|██████████| 100/100 [00:00<00:00, 137.85it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 168.54it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 141.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.88it/s]
# 100%|██████████| 100/100 [00:00<00:00, 211.29it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 123.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.79it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 198.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.88it/s]
# 100%|██████████| 100/100 [00:00<00:00, 131.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 155.72it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.06it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 162.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.98it/s]
# 100%|██████████| 100/100 [00:00<00:00, 202.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 141.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 174.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.69it/s]
# 100%|██████████| 100/100 [00:00<00:00, 197.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.52it/s]
# 100%|██████████| 100/100 [00:00<00:00, 162.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 145.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 163.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 221.48it/s]
# 100%|██████████| 100/100 [00:00<00:00, 221.62it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 237.02it/s]
# 100%|██████████| 100/100 [00:00<00:00, 148.72it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 199.88it/s]
# 100%|██████████| 100/100 [00:00<00:00, 220.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 195.19it/s]
# 100%|██████████| 100/100 [00:00<00:00, 147.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.93it/s]
# 100%|██████████| 100/100 [00:00<00:00, 151.47it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.51it/s]
# 100%|██████████| 100/100 [00:00<00:00, 166.34it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.81it/s]
# 100%|██████████| 100/100 [00:00<00:00, 123.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.96it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.22it/s]
# 100%|██████████| 100/100 [00:00<00:00, 135.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.48it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 144.70it/s]
# 100%|██████████| 100/100 [00:00<00:00, 238.66it/s]
# 100%|██████████| 100/100 [00:00<00:00, 218.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 164.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 215.52it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.06it/s]
# 100%|██████████| 100/100 [00:00<00:00, 118.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 207.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 223.54it/s]
# 100%|██████████| 100/100 [00:00<00:00, 147.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 199.48it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.23it/s]
# 100%|██████████| 100/100 [00:00<00:00, 231.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 203.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 135.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 209.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 174.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 244.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 153.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 144.48it/s]
# 100%|██████████| 100/100 [00:00<00:00, 130.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 191.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.50it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 132.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 204.91it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 133.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 199.34it/s]
# 100%|██████████| 100/100 [00:00<00:00, 154.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.22it/s]
# 100%|██████████| 100/100 [00:00<00:00, 150.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 199.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 228.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 162.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 146.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 215.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 211.19it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 169.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 116.72it/s]
# 100%|██████████| 100/100 [00:00<00:00, 195.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 203.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 233.18it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 209.28it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 136.14it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 203.18it/s]
# 100%|██████████| 100/100 [00:00<00:00, 139.93it/s]
# 100%|██████████| 100/100 [00:00<00:00, 217.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 223.33it/s]
# 100%|██████████| 100/100 [00:00<00:00, 124.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.54it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 230.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 199.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 237.69it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.54it/s]
# 100%|██████████| 100/100 [00:00<00:00, 220.12it/s]
# 100%|██████████| 100/100 [00:00<00:00, 156.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 134.70it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.02it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.04it/s]
# 100%|██████████| 100/100 [00:00<00:00, 206.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 191.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 114.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.52it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.87it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 131.19it/s]
# 100%|██████████| 100/100 [00:00<00:00, 174.36it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.18it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.81it/s]
# 100%|██████████| 100/100 [00:01<00:00, 83.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 127.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 100.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 117.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 154.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 124.27it/s]
# 100%|██████████| 100/100 [00:01<00:00, 97.91it/s]
# 100%|██████████| 100/100 [00:01<00:00, 56.79it/s]
# 100%|██████████| 100/100 [00:00<00:00, 115.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 125.92it/s]
# 100%|██████████| 100/100 [00:01<00:00, 66.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 159.87it/s]
# 100%|██████████| 100/100 [00:00<00:00, 152.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 117.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 212.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 145.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 132.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 123.06it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.86it/s]
# 100%|██████████| 100/100 [00:00<00:00, 111.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 132.22it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.36it/s]
# 100%|██████████| 100/100 [00:00<00:00, 146.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 105.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.15it/s]
# 100%|██████████| 100/100 [00:00<00:00, 129.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 109.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 126.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 112.59it/s]
# 100%|██████████| 100/100 [00:00<00:00, 127.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.15it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 110.67it/s]
# 100%|██████████| 100/100 [00:00<00:00, 148.82it/s]
# 100%|██████████| 100/100 [00:00<00:00, 152.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 110.02it/s]
# 100%|██████████| 100/100 [00:00<00:00, 144.15it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.85it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.81it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 139.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 186.00it/s]
# 100%|██████████| 100/100 [00:01<00:00, 93.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 198.47it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.81it/s]
# 100%|██████████| 100/100 [00:00<00:00, 108.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 115.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 140.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 128.23it/s]
# 100%|██████████| 100/100 [00:00<00:00, 113.22it/s]
# 100%|██████████| 100/100 [00:00<00:00, 136.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 156.07it/s]
# 100%|██████████| 100/100 [00:00<00:00, 133.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 146.37it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.55it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 107.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.50it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.29it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.17it/s]
# 100%|██████████| 100/100 [00:00<00:00, 120.05it/s]
# 100%|██████████| 100/100 [00:00<00:00, 122.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 129.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 115.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 124.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 160.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 124.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 130.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 164.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 144.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 151.18it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 222.97it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 116.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 127.63it/s]
# 100%|██████████| 100/100 [00:01<00:00, 97.89it/s]
# 100%|██████████| 100/100 [00:01<00:00, 99.23it/s]
# 100%|██████████| 100/100 [00:00<00:00, 134.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 152.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 135.27it/s]
# 100%|██████████| 100/100 [00:00<00:00, 160.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 191.41it/s]
# 100%|██████████| 100/100 [00:00<00:00, 134.83it/s]
# 100%|██████████| 100/100 [00:00<00:00, 168.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 156.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 152.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 119.15it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.96it/s]
# 100%|██████████| 100/100 [00:00<00:00, 101.67it/s]
# 100%|██████████| 100/100 [00:00<00:00, 133.98it/s]
# 100%|██████████| 100/100 [00:00<00:00, 195.48it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.41it/s]
# 100%|██████████| 100/100 [00:00<00:00, 154.51it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.99it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.96it/s]
# 100%|██████████| 100/100 [00:00<00:00, 202.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 163.35it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 227.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 211.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.67it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.47it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.95it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 167.58it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 161.41it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.54it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.00it/s]
# 100%|██████████| 100/100 [00:00<00:00, 150.01it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.80it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.98it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.47it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 161.40it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.87it/s]
# 100%|██████████| 100/100 [00:00<00:00, 169.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.06it/s]
# 100%|██████████| 100/100 [00:00<00:00, 174.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.72it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.46it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.30it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.04it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.82it/s]
# 100%|██████████| 100/100 [00:00<00:00, 169.02it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.85it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 152.70it/s]
# 100%|██████████| 100/100 [00:00<00:00, 152.78it/s]
# 100%|██████████| 100/100 [00:00<00:00, 212.22it/s]
# 100%|██████████| 100/100 [00:00<00:00, 157.33it/s]
# 100%|██████████| 100/100 [00:00<00:00, 172.41it/s]
# 100%|██████████| 100/100 [00:00<00:00, 164.33it/s]
# 100%|██████████| 100/100 [00:00<00:00, 231.67it/s]
# 100%|██████████| 100/100 [00:00<00:00, 159.25it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.69it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.79it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.56it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.72it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.77it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.50it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 210.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.42it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.54it/s]
# 100%|██████████| 100/100 [00:00<00:00, 224.23it/s]
# 100%|██████████| 100/100 [00:00<00:00, 162.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 193.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 202.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.38it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.70it/s]
# 100%|██████████| 100/100 [00:00<00:00, 162.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.28it/s]
# 100%|██████████| 100/100 [00:00<00:00, 206.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.39it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.29it/s]
# 100%|██████████| 100/100 [00:00<00:00, 181.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.79it/s]
# 100%|██████████| 100/100 [00:00<00:00, 169.38it/s]
# 100%|██████████| 100/100 [00:00<00:00, 179.24it/s]
# 100%|██████████| 100/100 [00:00<00:00, 166.71it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.03it/s]
# 100%|██████████| 100/100 [00:00<00:00, 189.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 187.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 169.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 192.31it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.29it/s]
# 100%|██████████| 100/100 [00:00<00:00, 165.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 199.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.89it/s]
# 100%|██████████| 100/100 [00:00<00:00, 226.44it/s]
# 100%|██████████| 100/100 [00:00<00:00, 161.65it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.60it/s]
# 100%|██████████| 100/100 [00:00<00:00, 177.95it/s]
# 100%|██████████| 100/100 [00:00<00:00, 160.74it/s]
# 100%|██████████| 100/100 [00:00<00:00, 219.92it/s]
# 100%|██████████| 100/100 [00:00<00:00, 196.23it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.73it/s]
# 100%|██████████| 100/100 [00:00<00:00, 200.11it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.70it/s]
# 100%|██████████| 100/100 [00:00<00:00, 219.38it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 185.10it/s]
# 100%|██████████| 100/100 [00:00<00:00, 201.38it/s]
# 100%|██████████| 100/100 [00:00<00:00, 202.12it/s]
# 100%|██████████| 100/100 [00:00<00:00, 194.23it/s]
# 100%|██████████| 100/100 [00:00<00:00, 184.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 188.63it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.53it/s]
# 100%|██████████| 100/100 [00:00<00:00, 221.38it/s]
# 100%|██████████| 100/100 [00:00<00:00, 205.34it/s]
# 100%|██████████| 100/100 [00:00<00:00, 197.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 190.22it/s]
# 100%|██████████| 100/100 [00:00<00:00, 169.34it/s]
# 100%|██████████| 100/100 [00:00<00:00, 171.37it/s]
# 100%|██████████| 100/100 [00:00<00:00, 199.09it/s]
# 100%|██████████| 100/100 [00:00<00:00, 180.94it/s]
# 100%|██████████| 100/100 [00:00<00:00, 178.20it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.08it/s]
# 100%|██████████| 100/100 [00:00<00:00, 173.64it/s]
# 100%|██████████| 100/100 [00:00<00:00, 182.43it/s]
# 100%|██████████| 100/100 [00:00<00:00, 176.61it/s]
# 100%|██████████| 100/100 [00:00<00:00, 168.21it/s]
# 100%|██████████| 100/100 [00:00<00:00, 170.13it/s]
# 100%|██████████| 100/100 [00:00<00:00, 203.49it/s]
# 100%|██████████| 100/100 [00:00<00:00, 199.26it/s]
# 100%|██████████| 100/100 [00:00<00:00, 175.68it/s]
# 100%|██████████| 100/100 [00:00<00:00, 183.50it/s]

# %%
x_train, x_val, x_test = td_array, val_array, test_array
y_train, y_val, y_test = np.array(label_y), np.array(val_y), np.array(test_y)

# %%
x_train = np.expand_dims(x_train, axis=-1)
x_val = np.expand_dims(x_val, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# Convert labels to integers if necessary
y_train = y_train.astype(np.int64)
y_val = y_val.astype(np.int64)
y_test = y_test.astype(np.int64)

# %%
"""
    The GeneticAlgorithm is run with the parameters passed in. 
"""
ga = GeneticAlgorithm(
    population_size=10,
    num_generations=5,
    mutation_rate=0.3,
    x_train=x_train,
    y_train=y_train,
    x_val=x_val,
    y_val=y_val,
    verbose=True
)

history, parameter_history, fitness_history  = ga.evolve()
# Out:
# Added unique gene: [119, 24, 5, 15, 3]
# Added unique gene: [18, 70, 7, 20, 3]
# Added unique gene: [102, 12, 5, 69, 7]
# Added unique gene: [39, 27, 3, 89, 5]
# Added unique gene: [126, 65, 5, 45, 3]
# Added unique gene: [50, 20, 5, 27, 5]
# Added unique gene: [110, 25, 7, 72, 9]
# Added unique gene: [86, 26, 3, 65, 3]
# Added unique gene: [93, 42, 9, 44, 5]
# Added unique gene: [90, 25, 3, 23, 7]
# Initialized GA with 10 genes.
#
# Starting Generation 1/5
# Training model with batch size 119 and filters: [24, 15].
# 1614/1614 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.4557 - loss: 3.6998 - val_accuracy: 0.8475 - val_loss: 0.4807
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8562 - loss: 0.4608
# Gene [119, 24, 5, 15, 3] evaluated with fitness: 0.8475000262260437
# Training model with batch size 18 and filters: [70, 20].
# 10667/10667 ━━━━━━━━━━━━━━━━━━━━ 43s 4ms/step - accuracy: 0.6925 - loss: 1.1877 - val_accuracy: 0.8896 - val_loss: 0.3748
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8973 - loss: 0.3551
# Gene [18, 70, 7, 20, 3] evaluated with fitness: 0.8896458148956299
# Training model with batch size 102 and filters: [12, 69].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 66s 35ms/step - accuracy: 0.7277 - loss: 3.1669 - val_accuracy: 0.9184 - val_loss: 0.2606
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9278 - loss: 0.2332
# Gene [102, 12, 5, 69, 7] evaluated with fitness: 0.9184166789054871
# Training model with batch size 39 and filters: [27, 89].
# 4924/4924 ━━━━━━━━━━━━━━━━━━━━ 137s 28ms/step - accuracy: 0.7933 - loss: 1.7340 - val_accuracy: 0.9251 - val_loss: 0.2473
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9305 - loss: 0.2341
# Gene [39, 27, 3, 89, 5] evaluated with fitness: 0.925125002861023
# Training model with batch size 126 and filters: [65, 45].
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 57s 37ms/step - accuracy: 0.7274 - loss: 2.4752 - val_accuracy: 0.9149 - val_loss: 0.2770
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9230 - loss: 0.2553
# Gene [126, 65, 5, 45, 3] evaluated with fitness: 0.9148958325386047
# Training model with batch size 50 and filters: [20, 27].
# 3840/3840 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - accuracy: 0.6406 - loss: 2.1284 - val_accuracy: 0.8945 - val_loss: 0.3390
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8985 - loss: 0.3306
# Gene [50, 20, 5, 27, 5] evaluated with fitness: 0.8944791555404663
# Training model with batch size 110 and filters: [25, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 177s 101ms/step - accuracy: 0.7167 - loss: 2.6438 - val_accuracy: 0.9363 - val_loss: 0.2136
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9443 - loss: 0.1898
# Gene [110, 25, 7, 72, 9] evaluated with fitness: 0.9362708330154419
# Training model with batch size 86 and filters: [26, 65].
# 2233/2233 ━━━━━━━━━━━━━━━━━━━━ 49s 21ms/step - accuracy: 0.7451 - loss: 4.5175 - val_accuracy: 0.9035 - val_loss: 0.3072
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9132 - loss: 0.2814
# Gene [86, 26, 3, 65, 3] evaluated with fitness: 0.9035208225250244
# Training model with batch size 93 and filters: [42, 44].
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 79s 38ms/step - accuracy: 0.6300 - loss: 2.4076 - val_accuracy: 0.9131 - val_loss: 0.2903
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9216 - loss: 0.2648
# Gene [93, 42, 9, 44, 5] evaluated with fitness: 0.9131458401679993
# Training model with batch size 90 and filters: [25, 23].
# 2134/2134 ━━━━━━━━━━━━━━━━━━━━ 84s 39ms/step - accuracy: 0.4304 - loss: 3.3280 - val_accuracy: 0.8641 - val_loss: 0.4399
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8744 - loss: 0.4138
# Gene [90, 25, 3, 23, 7] evaluated with fitness: 0.8641250133514404
# Best gene: [110, 25, 7, 72, 9] with fitness: 0.9362708330154419
# Selection phase completed. Population halved.
# Crossover phase initiated.
# Crossover produced: [126, 65, 5, 69, 7]
# Crossover produced: [39, 12, 3, 69, 5]
# Crossover produced: [39, 25, 3, 72, 9]
# Crossover produced: [102, 12, 5, 44, 5]
# Crossover produced: [110, 25, 5, 72, 7]
#
# Starting Generation 2/5
# Training model with batch size 110 and filters: [25, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 239s 136ms/step - accuracy: 0.7721 - loss: 3.4507 - val_accuracy: 0.9400 - val_loss: 0.2135
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - accuracy: 0.9476 - loss: 0.1851
# Gene [110, 25, 7, 72, 9] evaluated with fitness: 0.9399791955947876
# Training model with batch size 39 and filters: [27, 89].
# 4924/4924 ━━━━━━━━━━━━━━━━━━━━ 193s 39ms/step - accuracy: 0.7913 - loss: 2.2120 - val_accuracy: 0.9092 - val_loss: 0.2946
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.9174 - loss: 0.2655
# Gene [39, 27, 3, 89, 5] evaluated with fitness: 0.909166693687439
# Training model with batch size 102 and filters: [12, 69].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 101s 53ms/step - accuracy: 0.7541 - loss: 1.7281 - val_accuracy: 0.9256 - val_loss: 0.2394
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9309 - loss: 0.2200
# Gene [102, 12, 5, 69, 7] evaluated with fitness: 0.9256458282470703
# Training model with batch size 126 and filters: [65, 45].
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 74s 48ms/step - accuracy: 0.6636 - loss: 3.7569 - val_accuracy: 0.9098 - val_loss: 0.2953
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9209 - loss: 0.2579
# Gene [126, 65, 5, 45, 3] evaluated with fitness: 0.9097916483879089
# Training model with batch size 93 and filters: [42, 44].
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 83s 40ms/step - accuracy: 0.7024 - loss: 1.9031 - val_accuracy: 0.9100 - val_loss: 0.2985
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9157 - loss: 0.2875
# Gene [93, 42, 9, 44, 5] evaluated with fitness: 0.9100208282470703
# Training model with batch size 126 and filters: [65, 69].
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 424s 278ms/step - accuracy: 0.6930 - loss: 5.4534 - val_accuracy: 0.9305 - val_loss: 0.2232
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 24ms/step - accuracy: 0.9349 - loss: 0.2068
# Gene [126, 65, 5, 69, 7] evaluated with fitness: 0.9304583072662354
# Training model with batch size 39 and filters: [12, 69].
# 4924/4924 ━━━━━━━━━━━━━━━━━━━━ 81s 16ms/step - accuracy: 0.7482 - loss: 2.9464 - val_accuracy: 0.8936 - val_loss: 0.3544
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.8960 - loss: 0.3532
# Gene [39, 12, 3, 69, 5] evaluated with fitness: 0.893583357334137
# Training model with batch size 39 and filters: [25, 72].
# 4924/4924 ━━━━━━━━━━━━━━━━━━━━ 339s 69ms/step - accuracy: 0.6458 - loss: 2.1965 - val_accuracy: 0.9009 - val_loss: 0.3318
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 27s 18ms/step - accuracy: 0.9150 - loss: 0.2865
# Gene [39, 25, 3, 72, 9] evaluated with fitness: 0.9008749723434448
# Training model with batch size 102 and filters: [12, 44].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 42s 22ms/step - accuracy: 0.7179 - loss: 4.8509 - val_accuracy: 0.9148 - val_loss: 0.2694
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9223 - loss: 0.2503
# Gene [102, 12, 5, 44, 5] evaluated with fitness: 0.9148333072662354
# Training model with batch size 110 and filters: [25, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 182s 104ms/step - accuracy: 0.5966 - loss: 4.0762 - val_accuracy: 0.9093 - val_loss: 0.2982
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9130 - loss: 0.2896
# Gene [110, 25, 5, 72, 7] evaluated with fitness: 0.9092708230018616
# Best gene: [110, 25, 7, 72, 9] with fitness: 0.9399791955947876
# Selection phase completed. Population halved.
# Crossover phase initiated.
# Crossover produced: [102, 25, 5, 72, 9]
# Crossover produced: [110, 25, 7, 72, 7]
# Crossover produced: [126, 12, 5, 69, 7]
# Crossover produced: [93, 42, 5, 44, 5]
# Crossover produced: [102, 12, 5, 69, 5]
# Max crossover attempts reached, proceeding with available population.
#
# Starting Generation 3/5
# Training model with batch size 110 and filters: [25, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 238s 136ms/step - accuracy: 0.7578 - loss: 2.5615 - val_accuracy: 0.9312 - val_loss: 0.2281
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - accuracy: 0.9352 - loss: 0.2123
# Gene [110, 25, 7, 72, 9] evaluated with fitness: 0.9312083125114441
# Training model with batch size 126 and filters: [65, 69].
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 424s 278ms/step - accuracy: 0.7669 - loss: 3.2225 - val_accuracy: 0.9481 - val_loss: 0.1614
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 24ms/step - accuracy: 0.9505 - loss: 0.1586
# Gene [126, 65, 5, 69, 7] evaluated with fitness: 0.9481041431427002
# Training model with batch size 102 and filters: [12, 69].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 101s 53ms/step - accuracy: 0.7430 - loss: 3.9751 - val_accuracy: 0.9280 - val_loss: 0.2326
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9341 - loss: 0.2173
# Gene [102, 12, 5, 69, 7] evaluated with fitness: 0.9280208349227905
# Training model with batch size 102 and filters: [12, 44].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 42s 22ms/step - accuracy: 0.6897 - loss: 5.4013 - val_accuracy: 0.9057 - val_loss: 0.3115
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9170 - loss: 0.2767
# Gene [102, 12, 5, 44, 5] evaluated with fitness: 0.9057499766349792
# Training model with batch size 93 and filters: [42, 44].
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 83s 40ms/step - accuracy: 0.6544 - loss: 2.8904 - val_accuracy: 0.9125 - val_loss: 0.2914
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.9171 - loss: 0.2778
# Gene [93, 42, 9, 44, 5] evaluated with fitness: 0.9125416874885559
# Training model with batch size 102 and filters: [25, 72].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 304s 161ms/step - accuracy: 0.7409 - loss: 3.1912 - val_accuracy: 0.9338 - val_loss: 0.2130
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - accuracy: 0.9388 - loss: 0.1979
# Gene [102, 25, 5, 72, 9] evaluated with fitness: 0.9338333606719971
# Training model with batch size 110 and filters: [25, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 158s 90ms/step - accuracy: 0.7465 - loss: 3.1432 - val_accuracy: 0.9325 - val_loss: 0.2177
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9396 - loss: 0.1947
# Gene [110, 25, 7, 72, 7] evaluated with fitness: 0.9325416684150696
# Training model with batch size 126 and filters: [12, 69].
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 102s 67ms/step - accuracy: 0.6710 - loss: 5.2747 - val_accuracy: 0.9033 - val_loss: 0.3092
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9083 - loss: 0.2974
# Gene [126, 12, 5, 69, 7] evaluated with fitness: 0.9032708406448364
# Training model with batch size 93 and filters: [42, 44].
# 2065/2065 ━━━━━━━━━━━━━━━━━━━━ 114s 55ms/step - accuracy: 0.7580 - loss: 2.3992 - val_accuracy: 0.9229 - val_loss: 0.2510
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.9274 - loss: 0.2368
# Gene [93, 42, 5, 44, 5] evaluated with fitness: 0.9229166507720947
# Training model with batch size 102 and filters: [12, 69].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 62s 33ms/step - accuracy: 0.7456 - loss: 4.4484 - val_accuracy: 0.9270 - val_loss: 0.2317
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9328 - loss: 0.2104
# Gene [102, 12, 5, 69, 5] evaluated with fitness: 0.9270416498184204
# Best gene: [126, 65, 5, 69, 7] with fitness: 0.9481041431427002
# Selection phase completed. Population halved.
# Crossover phase initiated.
# Crossover produced: [126, 25, 5, 72, 9]
# Crossover produced: [102, 25, 7, 72, 7]
# Crossover produced: [110, 65, 7, 72, 7]
# Crossover produced: [102, 25, 7, 69, 7]
# Crossover produced: [110, 12, 7, 72, 7]
#
# Starting Generation 4/5
# Training model with batch size 126 and filters: [65, 69].
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 422s 276ms/step - accuracy: 0.7140 - loss: 5.1667 - val_accuracy: 0.9197 - val_loss: 0.2608
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 24ms/step - accuracy: 0.9233 - loss: 0.2544
# Gene [126, 65, 5, 69, 7] evaluated with fitness: 0.9196666479110718
# Training model with batch size 102 and filters: [25, 72].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 303s 160ms/step - accuracy: 0.7692 - loss: 3.5321 - val_accuracy: 0.9337 - val_loss: 0.2158
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - accuracy: 0.9376 - loss: 0.2082
# Gene [102, 25, 5, 72, 9] evaluated with fitness: 0.9337291717529297
# Training model with batch size 110 and filters: [25, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 156s 89ms/step - accuracy: 0.7131 - loss: 2.7617 - val_accuracy: 0.9272 - val_loss: 0.2330
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9336 - loss: 0.2134
# Gene [110, 25, 7, 72, 7] evaluated with fitness: 0.9272083044052124
# Training model with batch size 110 and filters: [25, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 237s 135ms/step - accuracy: 0.7885 - loss: 2.2748 - val_accuracy: 0.9366 - val_loss: 0.2103
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 20s 14ms/step - accuracy: 0.9422 - loss: 0.1937
# Gene [110, 25, 7, 72, 9] evaluated with fitness: 0.9366041421890259
# Training model with batch size 102 and filters: [12, 69].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 101s 53ms/step - accuracy: 0.7058 - loss: 4.0700 - val_accuracy: 0.8986 - val_loss: 0.3303
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9087 - loss: 0.2999
# Gene [102, 12, 5, 69, 7] evaluated with fitness: 0.8986250162124634
# Training model with batch size 126 and filters: [25, 72].
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 291s 190ms/step - accuracy: 0.6691 - loss: 5.4031 - val_accuracy: 0.9240 - val_loss: 0.2481
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - accuracy: 0.9286 - loss: 0.2292
# Gene [126, 25, 5, 72, 9] evaluated with fitness: 0.9240416884422302
# Training model with batch size 102 and filters: [25, 72].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 149s 79ms/step - accuracy: 0.7563 - loss: 3.0557 - val_accuracy: 0.9345 - val_loss: 0.2166
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9385 - loss: 0.2048
# Gene [102, 25, 7, 72, 7] evaluated with fitness: 0.9345208406448364
# Training model with batch size 110 and filters: [65, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 327s 187ms/step - accuracy: 0.7502 - loss: 3.4037 - val_accuracy: 0.9437 - val_loss: 0.1846
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - accuracy: 0.9496 - loss: 0.1648
# Gene [110, 65, 7, 72, 7] evaluated with fitness: 0.9437083601951599
# Training model with batch size 102 and filters: [25, 69].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 117s 62ms/step - accuracy: 0.7081 - loss: 2.9385 - val_accuracy: 0.9349 - val_loss: 0.2124
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9404 - loss: 0.1946
# Gene [102, 25, 7, 69, 7] evaluated with fitness: 0.9348958134651184
# Training model with batch size 110 and filters: [12, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 64s 36ms/step - accuracy: 0.7778 - loss: 3.0420 - val_accuracy: 0.9336 - val_loss: 0.2199
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9405 - loss: 0.1968
# Gene [110, 12, 7, 72, 7] evaluated with fitness: 0.9335625171661377
# Best gene: [110, 65, 7, 72, 7] with fitness: 0.9437083601951599
# Selection phase completed. Population halved.
# Crossover phase initiated.
# Crossover produced: [102, 65, 7, 72, 9]
# Crossover produced: [110, 25, 5, 72, 9]
# Crossover produced: [102, 65, 7, 72, 7]
# Crossover produced: [102, 25, 7, 69, 9]
# Crossover produced: [110, 25, 7, 69, 7]
#
# Starting Generation 5/5
# Training model with batch size 110 and filters: [65, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 260s 148ms/step - accuracy: 0.7774 - loss: 3.4331 - val_accuracy: 0.9418 - val_loss: 0.1839
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 23s 16ms/step - accuracy: 0.9488 - loss: 0.1629
# Gene [110, 65, 7, 72, 7] evaluated with fitness: 0.9418333172798157
# Training model with batch size 110 and filters: [25, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 174s 99ms/step - accuracy: 0.7740 - loss: 3.1792 - val_accuracy: 0.9432 - val_loss: 0.1851
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.9452 - loss: 0.1811
# Gene [110, 25, 7, 72, 9] evaluated with fitness: 0.9431666731834412
# Training model with batch size 102 and filters: [25, 69].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 119s 63ms/step - accuracy: 0.7281 - loss: 3.0701 - val_accuracy: 0.9286 - val_loss: 0.2300
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9357 - loss: 0.2116
# Gene [102, 25, 7, 69, 7] evaluated with fitness: 0.9286249876022339
# Training model with batch size 102 and filters: [25, 72].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 120s 63ms/step - accuracy: 0.7695 - loss: 3.3427 - val_accuracy: 0.9381 - val_loss: 0.2026
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9445 - loss: 0.1816
# Gene [102, 25, 7, 72, 7] evaluated with fitness: 0.9380833506584167
# Training model with batch size 102 and filters: [25, 72].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 225s 119ms/step - accuracy: 0.7469 - loss: 3.0105 - val_accuracy: 0.9318 - val_loss: 0.2184
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.9409 - loss: 0.1887
# Gene [102, 25, 5, 72, 9] evaluated with fitness: 0.9317708611488342
# Training model with batch size 102 and filters: [65, 72].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 408s 216ms/step - accuracy: 0.7912 - loss: 3.7863 - val_accuracy: 0.9433 - val_loss: 0.1821
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 36s 24ms/step - accuracy: 0.9479 - loss: 0.1669
# Gene [102, 65, 7, 72, 9] evaluated with fitness: 0.9433125257492065
# Training model with batch size 110 and filters: [25, 72].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 224s 128ms/step - accuracy: 0.7070 - loss: 4.3852 - val_accuracy: 0.9329 - val_loss: 0.2157
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.9365 - loss: 0.2040
# Gene [110, 25, 5, 72, 9] evaluated with fitness: 0.9328749775886536
# Training model with batch size 102 and filters: [65, 72].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 261s 138ms/step - accuracy: 0.3756 - loss: 4.7393 - val_accuracy: 0.9237 - val_loss: 0.2597
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 22s 15ms/step - accuracy: 0.9309 - loss: 0.2398
# Gene [102, 65, 7, 72, 7] evaluated with fitness: 0.9236875176429749
# Training model with batch size 102 and filters: [25, 69].
# 1883/1883 ━━━━━━━━━━━━━━━━━━━━ 178s 94ms/step - accuracy: 0.7786 - loss: 4.8592 - val_accuracy: 0.9380 - val_loss: 0.1933
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 15s 10ms/step - accuracy: 0.9421 - loss: 0.1839
# Gene [102, 25, 7, 69, 9] evaluated with fitness: 0.9380000233650208
# Training model with batch size 110 and filters: [25, 69].
# 1746/1746 ━━━━━━━━━━━━━━━━━━━━ 117s 67ms/step - accuracy: 0.6940 - loss: 5.0763 - val_accuracy: 0.9209 - val_loss: 0.2640
# Restoring model weights from the end of the best epoch: 1.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - accuracy: 0.9251 - loss: 0.2584
# Gene [110, 25, 7, 69, 7] evaluated with fitness: 0.9209166765213013
# Best gene: [102, 65, 7, 72, 9] with fitness: 0.9433125257492065
# Selection phase completed. Population halved.
# Crossover phase initiated.
# Crossover produced: [110, 25, 7, 69, 9]
# Crossover produced: [102, 25, 7, 72, 9]
# Max crossover attempts reached, proceeding with available population.

# %%
# import matplotlib.pyplot as plt

def plot_fitness(fitness_history):
    plt.figure(figsize=(10, 5))
    max_fitness = [max(fitness) for fitness in fitness_history]
    plt.plot(max_fitness, label='Max Fitness')
    plt.title('Fitness over Generations')
    plt.xlabel('Generation')
    plt.ylabel('Max Fitness')
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_parameter_distribution(parameter_history, generation, parameter_index):
    plt.figure(figsize=(10, 5))
    parameter_values = [gene[parameter_index] for gene in parameter_history[generation]]
    plt.hist(parameter_values, bins=20, alpha=0.75)
    plt.title(f'Distribution of Parameter at Index {parameter_index} in Generation {generation+1}')
    plt.xlabel('Parameter Value')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# Call these functions after running `evolve()`
plot_fitness(fitness_history)
plot_parameter_distribution(parameter_history, 0, 1)

# %%
history
# Out:
# [(0, [110, 25, 7, 72, 9], 0.9362708330154419),
#  (1, [110, 25, 7, 72, 9], 0.9399791955947876),
#  (2, [126, 65, 5, 69, 7], 0.9481041431427002),
#  (3, [110, 65, 7, 72, 7], 0.9437083601951599),
#  (4, [102, 65, 7, 72, 9], 0.9433125257492065)]

# %%
"""
    'history' contains tuples of (generation, best_gene, fitness) and best_gene is 
        [batch_size, num_filters]. The best gene is retrieved
"""
best_gene = sorted(history, key=lambda x: x[2], reverse=True)[0][1]
best_batch_size, best_layer_config = best_gene[0], best_gene[1:]
best_gene, best_batch_size, best_layer_config
# Out:
# ([126, 65, 5, 69, 7], 126, [65, 5, 69, 7])

# %%
# The best layer config from the best gene is used to instantiate the CNN model. 
best_model = CNNModel(best_layer_config,verbose=True)
# Out:
# c:\Users\Chulpan\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
# The instantiateed model is then trained for 10 epochs.
best_model.train(x_train, y_train, x_val, y_val, best_batch_size, epochs=10)
# Out:
# Training model with batch size 126 and filters: [65, 69].
# Epoch 1/10
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 359s 235ms/step - accuracy: 0.7446 - loss: 4.2528 - val_accuracy: 0.9376 - val_loss: 0.2082
# Epoch 2/10
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 318s 208ms/step - accuracy: 0.9506 - loss: 0.1560 - val_accuracy: 0.9542 - val_loss: 0.1465
# Epoch 3/10
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 321s 211ms/step - accuracy: 0.9611 - loss: 0.1202 - val_accuracy: 0.9493 - val_loss: 0.1704
# Epoch 4/10
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 364s 239ms/step - accuracy: 0.9639 - loss: 0.1127 - val_accuracy: 0.9565 - val_loss: 0.1548
# Epoch 5/10
# 1524/1524 ━━━━━━━━━━━━━━━━━━━━ 428s 281ms/step - accuracy: 0.9678 - loss: 0.1043 - val_accuracy: 0.9570 - val_loss: 0.1565
# Epoch 5: early stopping
# Restoring model weights from the end of the best epoch: 2.

# %%
index = np.random.randint(0, len(x_val))
random_image = x_val[index]
random_label = y_val[index]

plt.imshow(random_image.squeeze(), cmap='gray')
plt.title(f'Actual Label: {random_label}')
plt.show()

random_image_expanded = np.expand_dims(random_image, axis=0)
prediction = best_model.model.predict(random_image_expanded)
predicted_label = np.argmax(prediction)

print(f'Predicted Label: {predicted_label}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Predicted Label: 7

# %%
def pick_and_predict_single_image(trainpath):
    train_dirs = [d for d in os.listdir(trainpath) if os.path.isdir(os.path.join(trainpath, d))]
    chosen_dir = choice(train_dirs)
    full_path = os.path.join(trainpath, chosen_dir)
    image_name = choice(os.listdir(full_path))
    image_path = os.path.join(full_path, image_name)

    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    plt.figure(figsize=(6, 2))
    plt.imshow(img, cmap='gray')
    plt.title('Raw Image')
    plt.axis('off')
    plt.show()

    # Split the image
    img_array1 = img[:, :img.shape[1]//3]
    img_array2 = img[:, img.shape[1]//3:2*img.shape[1]//3]
    img_array3 = img[:, 2*img.shape[1]//3:]

    # Process each digit
    digits = [each_digit(img_array1), each_digit(img_array2), each_digit(img_array3)]

    # Predict each digit
    predictions = []
    for digit in digits:
        if digit is not None:
            digit = np.expand_dims(digit, axis=-1)
            digit = np.expand_dims(digit, axis=0)
            prediction = best_model.model.predict(digit)
            predicted_label = np.argmax(prediction)
            predictions.append(predicted_label)
        else:
            predictions.append(None)

    # Display results
    fig, axes = plt.subplots(1, 3, figsize=(10, 3))
    for i, ax in enumerate(axes):
        if digits[i] is not None:
            ax.imshow(digits[i], cmap='gray')
            ax.title.set_text(f'Predicted: {predictions[i]}')
        else:
            ax.imshow(np.zeros((28, 28)), cmap='gray')
            ax.title.set_text('No digit found')
        ax.axis('off')
    plt.show()

    return predictions

pick_and_predict_single_image(valpath)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# [9, 4, 0]
